# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
rng = np.random.default_rng(seed=12345)

positions = rng.integers(0, 2, size=(1_000_000, 2))
positions = np.where(positions == 0, 1, -1)
result = positions.cumsum(axis=0)

# %%
fig = plt.figure()
graph, = plt.plot([], [], 'b,')
plot.title("Brownian Motion 2D Simulation")
plt.xlim(-400, 400)
plt.ylim(-400, 400)

def animate(i):
    graph.set_data(result[:i + 1, 0], result[:i + 1, 1])
    return graph

ani = FuncAnimation(fig, animate, frames=5_000, interval=10)

# %%
from IPython.display import HTML
HTML(ani.to_html5_video())
# Out:
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...
